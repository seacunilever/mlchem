# %% [markdown]
# # CHEMICAL SPACE EXAMPLE

# %%
from mlchem.chem.visualise.space import ChemicalSpace
from mlchem.chem.manipulation import MolCleaner
from mlchem.chem.calculator import descriptors
from mlchem.ml.preprocessing.dimensional_reduction import Compressor
from mlchem.helper import identify_df_duplicates, add_inchi_to_dataframe, suppress_warnings
suppress_warnings()
import pandas as pd
import numpy as np

# %%
# this is the data generated in mol_generator example notebook
# CLASS 0 are random chemicals, CLASS 1 are alcohols

data = pd.read_csv('../data/data.csv')

# clean the structures
cleaner = MolCleaner(input_smiles_list=list(data.SMILES),id_list=list(data.index))
cleaner.full_clean()

# retain only the accepted molecules and add the SMILES column to the cleaned dataframe
df_data_cleaned = data[data.index.isin(list(cleaner.df_accepted.id))]
df_data_cleaned.loc[:,'SMILES'] = list(cleaner.df_accepted.SMILES)

# add the INCHI column to the cleaned dataframe and identify duplicates
df_data_cleaned = add_inchi_to_dataframe(df_data_cleaned,1,'SMILES')
df_added,df_duplicates = identify_df_duplicates(df_data_cleaned,'INCHI')

df_final = df_added.copy()
df_final.columns = ['SMILES','NAME','CLASS']
df_final['CLASS'] = df_final['CLASS'].astype('str')
# Out:
# Initialising SMILES
# Removing carbon ions
# Removing inorganics
# Removing organometallics
# Desalting SMILES
# Neutralising SMILES
# Performing quality check
# DONE

# %% [markdown]
# ### Calc descriptors

# %%
df_desc_rdkit = descriptors.get_rdkitDesc(df_final.SMILES)

df_desc_mordred = descriptors.get_mordredDesc(df_final.SMILES) # don't use if molecules are not cleaned
df_desc_both = descriptors.get_allDesc(df_final.SMILES) # don't use if molecules are not cleaned

df_fp_morgan_2 = descriptors.get_fingerprint_df(df_final.SMILES,fp_type='m',radius=2)
df_fp_morgan_4 = descriptors.get_fingerprint_df(df_final.SMILES,fp_type='m',radius=4)
df_chemotypes = descriptors.get_chemotypes(df_final.SMILES)

# %% [markdown]
# ##### Force numeric types on descriptors, drop inf and NaN

# %%
df_desc_selected = df_fp_morgan_2 # specify descriptor type: df_desc_rdkit, df_desc_mordred, df_desc_both, df_fp_morgan_2, df_fp_morgan_4, df_chemotypes

columns_to_keep = []
for c in df_desc_selected.columns:
    try:
        pd.to_numeric(df_desc_selected[c])
        columns_to_keep.append(c)
    except Exception:
        pass
df_desc_selected = df_desc_selected[columns_to_keep]

df_desc_selected.replace([np.inf, -np.inf], np.nan, inplace=True)
df_desc_selected.dropna(axis=0,inplace=True) # axis 0: rows, axis 1: columns

# %% [markdown]
# ### Use ChemicalSpace and Compressor classes

# %%
cs = ChemicalSpace(data=df_final,df_descriptors=df_desc_selected)

cs.process(diversity_filter=0.2,collinearity_filter=0.9,standardise=False)
# Out:
# Before filtering: (593, 2048)
# After diversity filter: (593, 126)
# After collinearity filter: (593, 126)

# %%
cs.df_processed
# Out:
#                                                     m2  m3  m14  m21  m32  \
# CO                                                   0   0    0    0    0
# C=NCCC(CCO)CCCCOC(=O)C=O                             1   0    1    0    0
# CCC=C=NC#CCC=NCCC(CCO)CCCCOC(=O)C=O                  1   0    1    0    0
# C#CCCCCOCCC=C=NC#CCC=NCCC(CCO)CCCCOC(=O)C=O          1   0    1    0    0
# O=CC(=O)OCCCCC(CCO)CCN=CCC#CN=C=CCCOCCCCC1=CCCC=C1   1   0    1    0    0
# ...                                                 ..  ..  ...  ...  ...
# CCCC(C)CCC1=C(C)C=C1                                 1   0    0    0    0
# CCCSCC=CC(C)CN=O                                     1   0    0    0    0
# CCCCC=O                                              0   0    0    0    0
# CCCC=CCCC(C)CCCC=CCO                                 1   0    0    0    0
# CCC(C)CCCC=CC=CCOCCCC=O                              1   0    1    0    0
#
#                                                     m40  m81  m117  m119  \
# CO                                                    0    0     0     0
# C=NCCC(CCO)CCCCOC(=O)C=O                              0    1     0     0
# CCC=C=NC#CCC=NCCC(CCO)CCCCOC(=O)C=O                   0    1     0     0
# C#CCCCCOCCC=C=NC#CCC=NCCC(CCO)CCCCOC(=O)C=O           0    1     0     0
# O=CC(=O)OCCCCC(CCO)CCN=CCC#CN=C=CCCOCCCCC1=CCCC=C1    0    1     0     0
# ...                                                 ...  ...   ...   ...
# CCCC(C)CCC1=C(C)C=C1                                  0    1     0     0
# CCCSCC=CC(C)CN=O                                      0    1     1     0
# CCCCC=O                                               0    1     0     1
# CCCC=CCCC(C)CCCC=CCO                                  0    1     0     0
# CCC(C)CCCC=CC=CCOCCCC=O                               0    1     0     1
#
#                                                     m145  ...  m1756  m1769  \
# CO                                                     0  ...      0      0
# C=NCCC(CCO)CCCCOC(=O)C=O                               1  ...      0      0
# CCC=C=NC#CCC=NCCC(CCO)CCCCOC(=O)C=O                    1  ...      0      0
# C#CCCCCOCCC=C=NC#CCC=NCCC(CCO)CCCCOC(=O)C=O            1  ...      0      0
# O=CC(=O)OCCCCC(CCO)CCN=CCC#CN=C=CCCOCCCCC1=CCCC=C1     1  ...      0      0
# ...                                                  ...  ...    ...    ...
# CCCC(C)CCC1=C(C)C=C1                                   0  ...      0      0
# CCCSCC=CC(C)CN=O                                       0  ...      0      0
# CCCCC=O                                                0  ...      0      0
# CCCC=CCCC(C)CCCC=CCO                                   0  ...      1      0
# CCC(C)CCCC=CC=CCOCCCC=O                                0  ...      0      0
#
#                                                     m1782  m1874  m1912  \
# CO                                                      0      0      0
# C=NCCC(CCO)CCCCOC(=O)C=O                                0      0      1
# CCC=C=NC#CCC=NCCC(CCO)CCCCOC(=O)C=O                     0      0      1
# C#CCCCCOCCC=C=NC#CCC=NCCC(CCO)CCCCOC(=O)C=O             0      0      1
# O=CC(=O)OCCCCC(CCO)CCN=CCC#CN=C=CCCOCCCCC1=CCCC=C1      1      1      1
# ...                                                   ...    ...    ...
# CCCC(C)CCC1=C(C)C=C1                                    0      1      0
# CCCSCC=CC(C)CN=O                                        0      0      0
# CCCCC=O                                                 0      0      1
# CCCC=CCCC(C)CCCC=CCO                                    0      0      1
# CCC(C)CCCC=CC=CCOCCCC=O                                 0      0      1
#
#                                                     m1924  m1928  m1952  \
# CO                                                      0      0      0
# C=NCCC(CCO)CCCCOC(=O)C=O                                0      0      0
# CCC=C=NC#CCC=NCCC(CCO)CCCCOC(=O)C=O                     0      0      0
# C#CCCCCOCCC=C=NC#CCC=NCCC(CCO)CCCCOC(=O)C=O             0      1      0
# O=CC(=O)OCCCCC(CCO)CCN=CCC#CN=C=CCCOCCCCC1=CCCC=C1      0      0      0
# ...                                                   ...    ...    ...
# CCCC(C)CCC1=C(C)C=C1                                    0      0      0
# CCCSCC=CC(C)CN=O                                        0      0      0
# CCCCC=O                                                 0      0      0
# CCCC=CCCC(C)CCCC=CCO                                    0      0      0
# CCC(C)CCCC=CC=CCOCCCC=O                                 0      0      0
#
#                                                     m1964  m1993
# CO                                                      0      0
# C=NCCC(CCO)CCCCOC(=O)C=O                                0      0
# CCC=C=NC#CCC=NCCC(CCO)CCCCOC(=O)C=O                     0      0
# C#CCCCCOCCC=C=NC#CCC=NCCC(CCO)CCCCOC(=O)C=O             1      1
# O=CC(=O)OCCCCC(CCO)CCN=CCC#CN=C=CCCOCCCCC1=CCCC=C1      0      1
# ...                                                   ...    ...
# CCCC(C)CCC1=C(C)C=C1                                    0      0
# CCCSCC=CC(C)CN=O                                        0      0
# CCCCC=O                                                 0      0
# CCCC=CCCC(C)CCCC=CCO                                    0      0
# CCC(C)CCCC=CC=CCOCCCC=O                                 0      1
#
# [593 rows x 126 columns]

# %%
c = Compressor(cs.df_processed) # initialise the compressor with the processed dataframe
c.compress_PCA(0.8) # first compression layer using PCA with 80% variance explained
c.compress_TSNE() # second compression layer using t-SNE

# folders with stuctures png files will be generated in the working directory, one for each class in the dataset.
# The png files will be used to plot the chemical space with the structures of the molecules.
cs.prepare(df_compressed=c.dataframe_compressed) # prepare the chemical space with the compressed dataframe

# %%
# plotting options to customise the chemical space plot with
cs.bokeh_dictionary = {'title_location':'above',
              'title_fontsize':'25px',
              'title_align':'center',
              'title_background_fill_colour':'white',
              'title_text_colour':'black',
              'legend_location':'top_left',
              'legend_title':'Class',
              'legend_label_text_font':'times',
              'legend_label_text_font_style':'italic',
              'legend_label_text_colour':'navy',
              'legend_border_line_width':3,
              'legend_border_line_colour':'navy',
              'legend_border_line_alpha':0.5,
              'legend_background_fill_colour':'grey',
              'legend_background_fill_alpha':0.2,
              'xaxis_label':'DIM_1',
              'xaxis_line_width':3,
              'xaxis_line_colour':'grey',
              'xaxis_major_label_text_colour':'navy',
              'xaxis_major_label_orientation':'horizontal',
              'yaxis_label':'DIM_2',
              'yaxis_line_width':3,
              'yaxis_line_colour':'grey',
              'yaxis_major_label_text_colour':'navy',
              'yaxis_major_label_orientation':'vertical',
              'axis_minor_tick_in':-3,
              'axis_minor_tick_out':6,
              }

# plot the chemical space and save it as an interactive HTML file
cs.plot(filename='demo',title='demo',save_html=True,
        colour_list=['blue','magenta','green'],
        )
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ae467f62-e3af-4b00-adf3-0d9e84db51dd">Loading BokehJS ...</span>
#     </div>
