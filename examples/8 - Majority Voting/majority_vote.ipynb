# %% [markdown]
# # MAJORITY VOTE DEMO

# %%
import joblib
import pandas as pd
import numpy as np
import glob

from mlchem.ml.preprocessing.scaling import scale_df_standard,transform_df
from mlchem.helper import suppress_warnings
suppress_warnings()
from mlchem.metrics import get_geometric_S
from mlchem.ml.modelling.model_evaluation import MajorityVote
from mlchem.ml.modelling.model_evaluation import y_scrambling as ys

import io
from contextlib import redirect_stdout


estimator_path_list = glob.glob('../data/*_estimator')
estimator_list = [joblib.load(e) for e in estimator_path_list]

column_path_list = glob.glob('../data/*_cols')
column_list = [joblib.load(e) for e in column_path_list]

estimator_names = [e[e.find('\\')+len('\\'):e.find('_estimator')] for e in estimator_path_list]

dict_estimators = {}
for n,e in zip(estimator_names,estimator_list):
    dict_estimators[n] = e
dict_estimators
# Out:
# {'KNN_3_COMB': KNeighborsClassifier(n_neighbors=3),
#  'KNN_3_SFS': KNeighborsClassifier(n_neighbors=3),
#  'KNN_5_COMB': KNeighborsClassifier(),
#  'KNN_5_SFS': KNeighborsClassifier(),
#  'KNN_7_COMB': KNeighborsClassifier(n_neighbors=7),
#  'KNN_7_SFS': KNeighborsClassifier(n_neighbors=7),
#  'KNN_9_COMB': KNeighborsClassifier(n_neighbors=9),
#  'KNN_9_SFS': KNeighborsClassifier(n_neighbors=9),
#  'LOGREG_l1ratio_0_C_0.1_COMB': LogisticRegression(C=0.1, l1_ratio=0, random_state=1, solver='liblinear'),
#  'LOGREG_l1ratio_0_C_0.1_SFS': LogisticRegression(C=0.1, l1_ratio=0, random_state=1, solver='liblinear'),
#  'LOGREG_l1ratio_0_C_1.0_COMB': LogisticRegression(l1_ratio=0, random_state=1, solver='liblinear'),
#  'LOGREG_l1ratio_0_C_1.0_SFS': LogisticRegression(l1_ratio=0, random_state=1, solver='liblinear'),
#  'LOGREG_l1ratio_0_C_10.0_COMB': LogisticRegression(C=10.0, l1_ratio=0, random_state=1, solver='liblinear'),
#  'LOGREG_l1ratio_0_C_10.0_SFS': LogisticRegression(C=10.0, l1_ratio=0, random_state=1, solver='liblinear'),
#  'LOGREG_l1ratio_1_C_0.1_COMB': LogisticRegression(C=0.1, l1_ratio=1, random_state=1, solver='liblinear'),
#  'LOGREG_l1ratio_1_C_0.1_SFS': LogisticRegression(C=0.1, l1_ratio=1, random_state=1, solver='liblinear'),
#  'LOGREG_l1ratio_1_C_1.0_COMB': LogisticRegression(l1_ratio=1, random_state=1, solver='liblinear'),
#  'LOGREG_l1ratio_1_C_1.0_SFS': LogisticRegression(l1_ratio=1, random_state=1, solver='liblinear'),
#  'LOGREG_l1ratio_1_C_10.0_COMB': LogisticRegression(C=10.0, l1_ratio=1, random_state=1, solver='liblinear'),
#  'LOGREG_l1ratio_1_C_10.0_SFS': LogisticRegression(C=10.0, l1_ratio=1, random_state=1, solver='liblinear'),
#  'LOGREG_l1_0.1_COMB': LogisticRegression(C=0.1, l1_ratio=None, penalty='l1', random_state=1,
#                     solver='liblinear'),
#  'LOGREG_l1_0.1_SFS': LogisticRegression(C=0.1, l1_ratio=None, penalty='l1', random_state=1,
#                     solver='liblinear'),
#  'LOGREG_l1_10_COMB': LogisticRegression(C=10, l1_ratio=None, penalty='l1', random_state=1,
#                     solver='liblinear'),
#  'LOGREG_l1_10_SFS': LogisticRegression(C=10, l1_ratio=None, penalty='l1', random_state=1,
#                     solver='liblinear'),
#  'LOGREG_l1_1_COMB': LogisticRegression(C=1, l1_ratio=None, penalty='l1', random_state=1,
#                     solver='liblinear'),
#  'LOGREG_l1_1_SFS': LogisticRegression(C=1, l1_ratio=None, penalty='l1', random_state=1,
#                     solver='liblinear'),
#  'LOGREG_l2_0.1_COMB': LogisticRegression(C=0.1, l1_ratio=None, penalty='l2', random_state=1,
#                     solver='liblinear'),
#  'LOGREG_l2_0.1_SFS': LogisticRegression(C=0.1, l1_ratio=None, penalty='l2', random_state=1,
#                     solver='liblinear'),
#  'LOGREG_l2_10_COMB': LogisticRegression(C=10, l1_ratio=None, penalty='l2', random_state=1,
#                     solver='liblinear'),
#  'LOGREG_l2_10_SFS': LogisticRegression(C=10, l1_ratio=None, penalty='l2', random_state=1,
#                     solver='liblinear'),
#  'LOGREG_l2_1_COMB': LogisticRegression(C=1, l1_ratio=None, penalty='l2', random_state=1,
#                     solver='liblinear'),
#  'LOGREG_l2_1_SFS': LogisticRegression(C=1, l1_ratio=None, penalty='l2', random_state=1,
#                     solver='liblinear')}

# %%
estimator_list
# Out:
# [KNeighborsClassifier(n_neighbors=3),
#  KNeighborsClassifier(n_neighbors=3),
#  KNeighborsClassifier(),
#  KNeighborsClassifier(),
#  KNeighborsClassifier(n_neighbors=7),
#  KNeighborsClassifier(n_neighbors=7),
#  KNeighborsClassifier(n_neighbors=9),
#  KNeighborsClassifier(n_neighbors=9),
#  LogisticRegression(C=0.1, l1_ratio=0, random_state=1, solver='liblinear'),
#  LogisticRegression(C=0.1, l1_ratio=0, random_state=1, solver='liblinear'),
#  LogisticRegression(l1_ratio=0, random_state=1, solver='liblinear'),
#  LogisticRegression(l1_ratio=0, random_state=1, solver='liblinear'),
#  LogisticRegression(C=10.0, l1_ratio=0, random_state=1, solver='liblinear'),
#  LogisticRegression(C=10.0, l1_ratio=0, random_state=1, solver='liblinear'),
#  LogisticRegression(C=0.1, l1_ratio=1, random_state=1, solver='liblinear'),
#  LogisticRegression(C=0.1, l1_ratio=1, random_state=1, solver='liblinear'),
#  LogisticRegression(l1_ratio=1, random_state=1, solver='liblinear'),
#  LogisticRegression(l1_ratio=1, random_state=1, solver='liblinear'),
#  LogisticRegression(C=10.0, l1_ratio=1, random_state=1, solver='liblinear'),
#  LogisticRegression(C=10.0, l1_ratio=1, random_state=1, solver='liblinear'),
#  LogisticRegression(C=0.1, l1_ratio=None, penalty='l1', random_state=1,
#                     solver='liblinear'),
#  LogisticRegression(C=0.1, l1_ratio=None, penalty='l1', random_state=1,
#                     solver='liblinear'),
#  LogisticRegression(C=10, l1_ratio=None, penalty='l1', random_state=1,
#                     solver='liblinear'),
#  LogisticRegression(C=10, l1_ratio=None, penalty='l1', random_state=1,
#                     solver='liblinear'),
#  LogisticRegression(C=1, l1_ratio=None, penalty='l1', random_state=1,
#                     solver='liblinear'),
#  LogisticRegression(C=1, l1_ratio=None, penalty='l1', random_state=1,
#                     solver='liblinear'),
#  LogisticRegression(C=0.1, l1_ratio=None, penalty='l2', random_state=1,
#                     solver='liblinear'),
#  LogisticRegression(C=0.1, l1_ratio=None, penalty='l2', random_state=1,
#                     solver='liblinear'),
#  LogisticRegression(C=10, l1_ratio=None, penalty='l2', random_state=1,
#                     solver='liblinear'),
#  LogisticRegression(C=10, l1_ratio=None, penalty='l2', random_state=1,
#                     solver='liblinear'),
#  LogisticRegression(C=1, l1_ratio=None, penalty='l2', random_state=1,
#                     solver='liblinear'),
#  LogisticRegression(C=1, l1_ratio=None, penalty='l2', random_state=1,
#                     solver='liblinear')]

# %%
estimator_path_list
# Out:
# ['../data\\KNN_3_COMB_estimator',
#  '../data\\KNN_3_SFS_estimator',
#  '../data\\KNN_5_COMB_estimator',
#  '../data\\KNN_5_SFS_estimator',
#  '../data\\KNN_7_COMB_estimator',
#  '../data\\KNN_7_SFS_estimator',
#  '../data\\KNN_9_COMB_estimator',
#  '../data\\KNN_9_SFS_estimator',
#  '../data\\LOGREG_l1ratio_0_C_0.1_COMB_estimator',
#  '../data\\LOGREG_l1ratio_0_C_0.1_SFS_estimator',
#  '../data\\LOGREG_l1ratio_0_C_1.0_COMB_estimator',
#  '../data\\LOGREG_l1ratio_0_C_1.0_SFS_estimator',
#  '../data\\LOGREG_l1ratio_0_C_10.0_COMB_estimator',
#  '../data\\LOGREG_l1ratio_0_C_10.0_SFS_estimator',
#  '../data\\LOGREG_l1ratio_1_C_0.1_COMB_estimator',
#  '../data\\LOGREG_l1ratio_1_C_0.1_SFS_estimator',
#  '../data\\LOGREG_l1ratio_1_C_1.0_COMB_estimator',
#  '../data\\LOGREG_l1ratio_1_C_1.0_SFS_estimator',
#  '../data\\LOGREG_l1ratio_1_C_10.0_COMB_estimator',
#  '../data\\LOGREG_l1ratio_1_C_10.0_SFS_estimator',
#  '../data\\LOGREG_l1_0.1_COMB_estimator',
#  '../data\\LOGREG_l1_0.1_SFS_estimator',
#  '../data\\LOGREG_l1_10_COMB_estimator',
#  '../data\\LOGREG_l1_10_SFS_estimator',
#  '../data\\LOGREG_l1_1_COMB_estimator',
#  '../data\\LOGREG_l1_1_SFS_estimator',
#  '../data\\LOGREG_l2_0.1_COMB_estimator',
#  '../data\\LOGREG_l2_0.1_SFS_estimator',
#  '../data\\LOGREG_l2_10_COMB_estimator',
#  '../data\\LOGREG_l2_10_SFS_estimator',
#  '../data\\LOGREG_l2_1_COMB_estimator',
#  '../data\\LOGREG_l2_1_SFS_estimator']

# %%
descriptor_types = ['rdkit']
scaling_decisions = [True]

dict_train_sets = {}
dict_test_sets = {}

dict_y_trains = {}
dict_y_tests = {}

for desc_type, scale in zip(descriptor_types, scaling_decisions):
    train_set_original = joblib.load(f'../data/train_set_{desc_type}')
    train_set, y_train = train_set_original.iloc[:, :-1], train_set_original.iloc[:, -1].values

    test_set_original = joblib.load(f'../data/test_set_{desc_type}')
    test_set, y_test = test_set_original.iloc[:, :-1], test_set_original.iloc[:, -1].values

    if scale:
        train_set_scaled, scaler = scale_df_standard(
            train_set,
            last_columns_to_preserve=0,
            skip_binary_columns=True,
        )
        test_set_scaled = transform_df(
            test_set,
            scaler,
            last_columns_to_preserve=0,
            skip_binary_columns=True,
        )[0]
    else:
        train_set_scaled = train_set
        test_set_scaled = test_set

    dict_train_sets[desc_type] = train_set_scaled
    dict_test_sets[desc_type] = test_set_scaled
    dict_y_trains[desc_type] = y_train
    dict_y_tests[desc_type] = y_test

big_train_set = pd.concat([trainset for trainset in dict_train_sets.values()], axis=1)
big_test_set = pd.concat([testset for testset in dict_test_sets.values()], axis=1)

# %%
big_train_set.head()
# Out:
#                           MaxAbsEStateIndex  MaxEStateIndex  \
# SMILES
# CCCCC(C)CCC                       -2.275207       -2.275207
# C1=CC2CCCC2O1                     -0.950214       -0.950214
# C=CCC=C(C=NCCC#CC=CC)NCO           0.615818        0.615818
# O=[N+]CC=NC#CO                     0.863868        0.863868
# O=CCC#CCO                          0.944862        0.944862
#
#                           MinAbsEStateIndex  MinEStateIndex       qed  \
# SMILES
# CCCCC(C)CCC                        0.820951        0.845857  1.443304
# C1=CC2CCCC2O1                      0.064270        0.210778  0.782349
# C=CCC=C(C=NCCC#CC=CC)NCO          -0.807000       -0.839315 -1.398373
# O=[N+]CC=NC#CO                    -0.987028       -0.688219  0.055173
# O=CCC#CCO                         -0.698412       -0.930453 -0.209184
#
#                                SPS     MolWt  HeavyAtomMolWt  ExactMolWt  \
# SMILES
# CCCCC(C)CCC               0.120536 -0.222067       -0.331742   -0.222047
# C1=CC2CCCC2O1             3.949329 -0.457538       -0.447795   -0.457449
# C=CCC=C(C=NCCC#CC=CC)NCO -0.168279  1.131575        1.173600    1.131800
# O=[N+]CC=NC#CO           -0.645222 -0.432408       -0.332364   -0.432019
# O=CCC#CCO                -0.857575 -0.614341       -0.563847   -0.614135
#
#                           NumValenceElectrons  ...  fr_pyridine  fr_quatN  \
# SMILES                                         ...
# CCCCC(C)CCC                         -0.041798  ...          0.0       0.0
# C1=CC2CCCC2O1                       -0.433195  ...          0.0       0.0
# C=CCC=C(C=NCCC#CC=CC)NCO             1.132392  ...          0.0       0.0
# O=[N+]CC=NC#CO                      -0.531044  ...          0.0       0.0
# O=CCC#CCO                           -0.628893  ...          0.0       0.0
#
#                           fr_sulfide  fr_sulfonamd  fr_sulfone  fr_tetrazole  \
# SMILES
# CCCCC(C)CCC                      0.0           0.0         0.0           0.0
# C1=CC2CCCC2O1                    0.0           0.0         0.0           0.0
# C=CCC=C(C=NCCC#CC=CC)NCO         0.0           0.0         0.0           0.0
# O=[N+]CC=NC#CO                   0.0           0.0         0.0           0.0
# O=CCC#CCO                        0.0           0.0         0.0           0.0
#
#                           fr_thiazole  fr_thiocyan  fr_thiophene  fr_urea
# SMILES
# CCCCC(C)CCC                       0.0          0.0           0.0      0.0
# C1=CC2CCCC2O1                     0.0          0.0           0.0      0.0
# C=CCC=C(C=NCCC#CC=CC)NCO          0.0          0.0           0.0      0.0
# O=[N+]CC=NC#CO                    0.0          0.0           0.0      0.0
# O=CCC#CCO                         0.0          0.0           0.0      0.0
#
# [5 rows x 204 columns]

# %%
big_test_set.head()
# Out:
#                  MaxAbsEStateIndex  MaxEStateIndex  MinAbsEStateIndex  \
# SMILES
# C#C[SH]=O                 0.736897        0.736897          -0.576518
# CCCCBC=CCCC=O             1.130166        1.130166           0.263610
# C1=CCCC=1                -1.999043       -1.999043           1.273359
# C=C(C)C                  -1.735791       -1.735791           1.195073
# CCCN1CCC2=C1C2C          -2.187080       -2.187080           0.621495
#
#                  MinEStateIndex       qed       SPS     MolWt  HeavyAtomMolWt  \
# SMILES
# C#C[SH]=O             -1.032759 -0.718343 -1.084407 -0.926476       -0.852641
# CCCCBC=CCCC=O          0.378083 -0.654275 -0.338100  0.087337        0.056078
# C1=CCCC=1              1.225561 -0.028563  0.652063 -1.030547       -1.026698
# C=C(C)C                1.159856 -0.087360 -0.847923 -1.160555       -1.200437
# CCCN1CCC2=C1C2C        0.678454  1.749396  2.246643 -0.105431       -0.129131
#
#                  ExactMolWt  NumValenceElectrons  ...  fr_pyridine  fr_quatN  \
# SMILES                                            ...
# C#C[SH]=O         -0.927263            -1.150756  ...          0.0       0.0
# CCCCBC=CCCC=O      0.090125             0.153900  ...          0.0       0.0
# C1=CCCC=1         -1.030566            -1.020290  ...          0.0       0.0
# C=C(C)C           -1.160539            -1.085523  ...          0.0       0.0
# CCCN1CCC2=C1C2C   -0.105358            -0.041798  ...          0.0       0.0
#
#                  fr_sulfide  fr_sulfonamd  fr_sulfone  fr_tetrazole  \
# SMILES
# C#C[SH]=O               0.0           0.0         0.0           0.0
# CCCCBC=CCCC=O           0.0           0.0         0.0           0.0
# C1=CCCC=1               0.0           0.0         0.0           0.0
# C=C(C)C                 0.0           0.0         0.0           0.0
# CCCN1CCC2=C1C2C         0.0           0.0         0.0           0.0
#
#                  fr_thiazole  fr_thiocyan  fr_thiophene  fr_urea
# SMILES
# C#C[SH]=O                0.0          0.0           0.0      0.0
# CCCCBC=CCCC=O            0.0          0.0           0.0      0.0
# C1=CCCC=1                0.0          0.0           0.0      0.0
# C=C(C)C                  0.0          0.0           0.0      0.0
# CCCN1CCC2=C1C2C          0.0          0.0           0.0      0.0
#
# [5 rows x 204 columns]

# %%
joblib.dump(big_train_set,'../data/big_train_set_scaled')
joblib.dump(big_test_set,'../data/big_test_set_scaled')
joblib.dump(y_train,'../data/y_train')
joblib.dump(y_test,'../data/y_test')
# Out:
# ['../data/y_test']

# %%
mv = MajorityVote(train_set=big_train_set,test_set=big_test_set,
                  y_train=y_train,y_test=y_test,
                  task_type='classification',
                  estimator_list=estimator_list,
                  column_list=column_list,
                  estimator_names=estimator_names)
mv.fit()
# Out:
# Fitting estimators: 100%|██████████| 32/32 [00:00<00:00, 46.52it/s]

# %% [markdown]
# ## Perform chance-correlation checks (y-scrambling)

# %%
import inspect
import re
import logging

yscrambling_threshold = 1.96/2.3 # include models with robustness at 5%
#yscrambling_threshold = 2.3/2.3 # include models with robustness at 1%
#yscrambling_threshold = 0 # include all models

def _extract_safety_margin(log_text):
    """Extract safety margin from logging output."""
    if not log_text:
        return np.nan
    
    # Pattern to match "safety margin : X.XXX" or similar variations
    m = re.search(
        r"safety[\s_-]*margin\s*[:=]\s*([-+]?\d*\.?\d+(?:[eE][-+]?\d+)?)",
        log_text,
        flags=re.IGNORECASE,
    )
    return float(m.group(1)) if m else np.nan


def _run_ys(estimator, X_train, X_test):
    sig = inspect.signature(ys)
    pool = {
        "estimator": estimator, "model": estimator, "clf": estimator,
        "X_train": X_train, "x_train": X_train, "train_set": X_train,
        "X_test": X_test, "x_test": X_test, "test_set": X_test,
        "y_train": y_train, "y_test": y_test, "metric_function":get_geometric_S,
        "n_iter":300,
        "n_jobs":-1, "plot":False,
    }
    kwargs = {k: v for k, v in pool.items() if k in sig.parameters}

    # Capture logging output instead of stdout
    log_capture = logging.StringIO() if hasattr(logging, 'StringIO') else io.StringIO()
    handler = logging.StreamHandler(log_capture)
    handler.setLevel(logging.INFO)
    logger_ys = logging.getLogger('mlchem.ml.modelling.model_evaluation')
    logger_ys.addHandler(handler)
    
    try:
        with io.StringIO() as buf, redirect_stdout(buf):
            try:
                out = ys(**kwargs)
            except TypeError:
                try:
                    out = ys(estimator, X_train, y_train, X_test, y_test)
                except TypeError:
                    out = ys(estimator, X_train, X_test, y_train, y_test)
        log = log_capture.getvalue()
    finally:
        logger_ys.removeHandler(handler)
    
    return out, log


rows = []
for name, est, cols in zip(estimator_names, estimator_list, column_list):
    Xtr, Xte = big_train_set[cols], big_test_set[cols]
    print(f'\n\nRunning y-scrambling for estimator: {name}')
    out, log = _run_ys(est, Xtr, Xte)
    margin = _extract_safety_margin(log)
    rows.append(
        {"estimator": name, "safety_margin": margin}
    )

df_yscrambling = pd.DataFrame(rows).sort_values(["safety_margin"], ascending=False)
# Filter downstream based on threshold
estimator_names_restricted = df_yscrambling.loc[df_yscrambling["safety_margin"] >= yscrambling_threshold, "estimator"].tolist()

display(df_yscrambling)
display(estimator_names_restricted)
# Out:
# Y-scrambling:   0%|          | 0/300 [00:00<?, ?it/s]
# Running y-scrambling for estimator: KNN_3_COMB
# Y-scrambling: 100%|██████████| 300/300 [00:02<00:00, 142.89it/s]
# 2026-08-04 14:59:06,974 - mlchem.ml.modelling.model_evaluation - INFO - Probability to obtain a better model by chance: 0.000
# 2026-08-04 14:59:06,974 - mlchem.ml.modelling.model_evaluation - INFO - Safety margin: 0.18
# Y-scrambling:   0%|          | 0/300 [00:00<?, ?it/s]
# Running y-scrambling for estimator: KNN_3_SFS
# Y-scrambling: 100%|██████████| 300/300 [00:02<00:00, 137.62it/s]
# 2026-08-04 14:59:09,280 - mlchem.ml.modelling.model_evaluation - INFO - Probability to obtain a better model by chance: 0.000
# 2026-08-04 14:59:09,280 - mlchem.ml.modelling.model_evaluation - INFO - Safety margin: 0.12
# Y-scrambling:   0%|          | 0/300 [00:00<?, ?it/s]
# Running y-scrambling for estimator: KNN_5_COMB
# Y-scrambling: 100%|██████████| 300/300 [00:02<00:00, 132.18it/s]
# 2026-08-04 14:59:11,767 - mlchem.ml.modelling.model_evaluation - INFO - Probability to obtain a better model by chance: 0.000
# 2026-08-04 14:59:11,768 - mlchem.ml.modelling.model_evaluation - INFO - Safety margin: 0.05
# Y-scrambling:   0%|          | 0/300 [00:00<?, ?it/s]
# Running y-scrambling for estimator: KNN_5_SFS
# Y-scrambling: 100%|██████████| 300/300 [00:02<00:00, 126.65it/s]
# 2026-08-04 14:59:14,275 - mlchem.ml.modelling.model_evaluation - INFO - Probability to obtain a better model by chance: 0.000
# 2026-08-04 14:59:14,277 - mlchem.ml.modelling.model_evaluation - INFO - Safety margin: 0.26
# Y-scrambling:   0%|          | 0/300 [00:00<?, ?it/s]
# Running y-scrambling for estimator: KNN_7_COMB
# Y-scrambling: 100%|██████████| 300/300 [00:01<00:00, 184.20it/s]
# 2026-08-04 14:59:16,059 - mlchem.ml.modelling.model_evaluation - INFO - Probability to obtain a better model by chance: 0.000
# 2026-08-04 14:59:16,060 - mlchem.ml.modelling.model_evaluation - INFO - Safety margin: 0.10
# Y-scrambling:   0%|          | 0/300 [00:00<?, ?it/s]
# Running y-scrambling for estimator: KNN_7_SFS
# Y-scrambling: 100%|██████████| 300/300 [00:01<00:00, 168.15it/s]
# 2026-08-04 14:59:17,964 - mlchem.ml.modelling.model_evaluation - INFO - Probability to obtain a better model by chance: 0.000
# 2026-08-04 14:59:17,966 - mlchem.ml.modelling.model_evaluation - INFO - Safety margin: 0.12
# Y-scrambling:   0%|          | 0/300 [00:00<?, ?it/s]
# Running y-scrambling for estimator: KNN_9_COMB
# Y-scrambling: 100%|██████████| 300/300 [00:01<00:00, 157.93it/s]
# 2026-08-04 14:59:19,976 - mlchem.ml.modelling.model_evaluation - INFO - Probability to obtain a better model by chance: 0.000
# 2026-08-04 14:59:19,994 - mlchem.ml.modelling.model_evaluation - INFO - Safety margin: 0.11
# Y-scrambling:   0%|          | 0/300 [00:00<?, ?it/s]
# Running y-scrambling for estimator: KNN_9_SFS
# Y-scrambling: 100%|██████████| 300/300 [00:02<00:00, 128.75it/s]
# 2026-08-04 14:59:22,487 - mlchem.ml.modelling.model_evaluation - INFO - Probability to obtain a better model by chance: 0.000
# 2026-08-04 14:59:22,487 - mlchem.ml.modelling.model_evaluation - INFO - Safety margin: 0.11
# Y-scrambling:   0%|          | 0/300 [00:00<?, ?it/s]
# Running y-scrambling for estimator: LOGREG_l1ratio_0_C_0.1_COMB
# Y-scrambling: 100%|██████████| 300/300 [00:01<00:00, 215.25it/s]
# 2026-08-04 14:59:24,019 - mlchem.ml.modelling.model_evaluation - INFO - Probability to obtain a better model by chance: 0.017
# 2026-08-04 14:59:24,022 - mlchem.ml.modelling.model_evaluation - INFO - Safety margin: -0.03
# Y-scrambling:   0%|          | 0/300 [00:00<?, ?it/s]
# Running y-scrambling for estimator: LOGREG_l1ratio_0_C_0.1_SFS
# Y-scrambling: 100%|██████████| 300/300 [00:01<00:00, 194.05it/s]
# 2026-08-04 14:59:25,701 - mlchem.ml.modelling.model_evaluation - INFO - Probability to obtain a better model by chance: 0.000
# 2026-08-04 14:59:25,702 - mlchem.ml.modelling.model_evaluation - INFO - Safety margin: 0.02
# Y-scrambling:   0%|          | 0/300 [00:00<?, ?it/s]
# Running y-scrambling for estimator: LOGREG_l1ratio_0_C_1.0_COMB
# Y-scrambling: 100%|██████████| 300/300 [00:01<00:00, 211.28it/s]
# 2026-08-04 14:59:27,285 - mlchem.ml.modelling.model_evaluation - INFO - Probability to obtain a better model by chance: 0.003
# 2026-08-04 14:59:27,285 - mlchem.ml.modelling.model_evaluation - INFO - Safety margin: 0.00
# Y-scrambling:   0%|          | 0/300 [00:00<?, ?it/s]
# Running y-scrambling for estimator: LOGREG_l1ratio_0_C_1.0_SFS
# Y-scrambling: 100%|██████████| 300/300 [00:01<00:00, 194.35it/s]
# 2026-08-04 14:59:28,955 - mlchem.ml.modelling.model_evaluation - INFO - Probability to obtain a better model by chance: 0.007
# 2026-08-04 14:59:28,956 - mlchem.ml.modelling.model_evaluation - INFO - Safety margin: -0.02
# Y-scrambling:   9%|▉         | 27/300 [00:00<00:01, 266.76it/s]
# Running y-scrambling for estimator: LOGREG_l1ratio_0_C_10.0_COMB
# Y-scrambling: 100%|██████████| 300/300 [00:01<00:00, 227.05it/s]
# 2026-08-04 14:59:30,378 - mlchem.ml.modelling.model_evaluation - INFO - Probability to obtain a better model by chance: 0.007
# 2026-08-04 14:59:30,378 - mlchem.ml.modelling.model_evaluation - INFO - Safety margin: -0.01
# Y-scrambling:   0%|          | 0/300 [00:00<?, ?it/s]
# Running y-scrambling for estimator: LOGREG_l1ratio_0_C_10.0_SFS
# Y-scrambling: 100%|██████████| 300/300 [00:01<00:00, 216.60it/s]
# 2026-08-04 14:59:31,868 - mlchem.ml.modelling.model_evaluation - INFO - Probability to obtain a better model by chance: 0.007
# 2026-08-04 14:59:31,870 - mlchem.ml.modelling.model_evaluation - INFO - Safety margin: -0.01
# Y-scrambling:   0%|          | 0/300 [00:00<?, ?it/s]
# Running y-scrambling for estimator: LOGREG_l1ratio_1_C_0.1_COMB
# Y-scrambling: 100%|██████████| 300/300 [00:01<00:00, 241.31it/s]
# 2026-08-04 14:59:33,229 - mlchem.ml.modelling.model_evaluation - INFO - Probability to obtain a better model by chance: 0.000
# 2026-08-04 14:59:33,230 - mlchem.ml.modelling.model_evaluation - INFO - Safety margin: 0.01
# Y-scrambling:   0%|          | 0/300 [00:00<?, ?it/s]
# Running y-scrambling for estimator: LOGREG_l1ratio_1_C_0.1_SFS
# Y-scrambling: 100%|██████████| 300/300 [00:01<00:00, 241.45it/s]
# 2026-08-04 14:59:34,604 - mlchem.ml.modelling.model_evaluation - INFO - Probability to obtain a better model by chance: 0.010
# 2026-08-04 14:59:34,604 - mlchem.ml.modelling.model_evaluation - INFO - Safety margin: -0.02
# Y-scrambling:   0%|          | 0/300 [00:00<?, ?it/s]
# Running y-scrambling for estimator: LOGREG_l1ratio_1_C_1.0_COMB
# Y-scrambling: 100%|██████████| 300/300 [00:01<00:00, 185.99it/s]
# 2026-08-04 14:59:36,336 - mlchem.ml.modelling.model_evaluation - INFO - Probability to obtain a better model by chance: 0.003
# 2026-08-04 14:59:36,339 - mlchem.ml.modelling.model_evaluation - INFO - Safety margin: 0.00
# Y-scrambling:   0%|          | 0/300 [00:00<?, ?it/s]
# Running y-scrambling for estimator: LOGREG_l1ratio_1_C_1.0_SFS
# Y-scrambling: 100%|██████████| 300/300 [00:01<00:00, 208.70it/s]
# 2026-08-04 14:59:37,937 - mlchem.ml.modelling.model_evaluation - INFO - Probability to obtain a better model by chance: 0.007
# 2026-08-04 14:59:37,937 - mlchem.ml.modelling.model_evaluation - INFO - Safety margin: 0.00
# Y-scrambling:   9%|▉         | 28/300 [00:00<00:00, 279.93it/s]
# Running y-scrambling for estimator: LOGREG_l1ratio_1_C_10.0_COMB
# Y-scrambling: 100%|██████████| 300/300 [00:01<00:00, 224.33it/s]
# 2026-08-04 14:59:39,392 - mlchem.ml.modelling.model_evaluation - INFO - Probability to obtain a better model by chance: 0.003
# 2026-08-04 14:59:39,393 - mlchem.ml.modelling.model_evaluation - INFO - Safety margin: -0.02
# Y-scrambling:   8%|▊         | 25/300 [00:00<00:01, 235.19it/s]
# Running y-scrambling for estimator: LOGREG_l1ratio_1_C_10.0_SFS
# Y-scrambling: 100%|██████████| 300/300 [00:01<00:00, 176.82it/s]
# 2026-08-04 14:59:41,151 - mlchem.ml.modelling.model_evaluation - INFO - Probability to obtain a better model by chance: 0.007
# 2026-08-04 14:59:41,151 - mlchem.ml.modelling.model_evaluation - INFO - Safety margin: -0.02
# Y-scrambling:   0%|          | 0/300 [00:00<?, ?it/s]
# Running y-scrambling for estimator: LOGREG_l1_0.1_COMB
# Y-scrambling: 100%|██████████| 300/300 [00:01<00:00, 187.87it/s]
# 2026-08-04 14:59:42,884 - mlchem.ml.modelling.model_evaluation - INFO - Probability to obtain a better model by chance: 0.007
# 2026-08-04 14:59:42,884 - mlchem.ml.modelling.model_evaluation - INFO - Safety margin: -0.02
# Y-scrambling:   0%|          | 0/300 [00:00<?, ?it/s]
# Running y-scrambling for estimator: LOGREG_l1_0.1_SFS
# Y-scrambling: 100%|██████████| 300/300 [00:01<00:00, 165.86it/s]
# 2026-08-04 14:59:44,886 - mlchem.ml.modelling.model_evaluation - INFO - Probability to obtain a better model by chance: 0.007
# 2026-08-04 14:59:44,886 - mlchem.ml.modelling.model_evaluation - INFO - Safety margin: 0.00
# Y-scrambling:   0%|          | 0/300 [00:00<?, ?it/s]
# Running y-scrambling for estimator: LOGREG_l1_10_COMB
# Y-scrambling: 100%|██████████| 300/300 [00:01<00:00, 205.63it/s]
# 2026-08-04 14:59:46,449 - mlchem.ml.modelling.model_evaluation - INFO - Probability to obtain a better model by chance: 0.003
# 2026-08-04 14:59:46,449 - mlchem.ml.modelling.model_evaluation - INFO - Safety margin: -0.02
# Y-scrambling:   0%|          | 0/300 [00:00<?, ?it/s]
# Running y-scrambling for estimator: LOGREG_l1_10_SFS
# Y-scrambling: 100%|██████████| 300/300 [00:01<00:00, 206.49it/s]
# 2026-08-04 14:59:48,002 - mlchem.ml.modelling.model_evaluation - INFO - Probability to obtain a better model by chance: 0.000
# 2026-08-04 14:59:48,002 - mlchem.ml.modelling.model_evaluation - INFO - Safety margin: 0.04
# Y-scrambling:   0%|          | 0/300 [00:00<?, ?it/s]
# Running y-scrambling for estimator: LOGREG_l1_1_COMB
# Y-scrambling: 100%|██████████| 300/300 [00:01<00:00, 224.52it/s]
# 2026-08-04 14:59:49,468 - mlchem.ml.modelling.model_evaluation - INFO - Probability to obtain a better model by chance: 0.000
# 2026-08-04 14:59:49,468 - mlchem.ml.modelling.model_evaluation - INFO - Safety margin: 0.05
# Y-scrambling:   0%|          | 0/300 [00:00<?, ?it/s]
# Running y-scrambling for estimator: LOGREG_l1_1_SFS
# Y-scrambling: 100%|██████████| 300/300 [00:01<00:00, 178.19it/s]
# 2026-08-04 14:59:51,268 - mlchem.ml.modelling.model_evaluation - INFO - Probability to obtain a better model by chance: 0.000
# 2026-08-04 14:59:51,268 - mlchem.ml.modelling.model_evaluation - INFO - Safety margin: 0.04
# Y-scrambling:   0%|          | 0/300 [00:00<?, ?it/s]
# Running y-scrambling for estimator: LOGREG_l2_0.1_COMB
# Y-scrambling: 100%|██████████| 300/300 [00:01<00:00, 237.92it/s]
# 2026-08-04 14:59:52,637 - mlchem.ml.modelling.model_evaluation - INFO - Probability to obtain a better model by chance: 0.000
# 2026-08-04 14:59:52,638 - mlchem.ml.modelling.model_evaluation - INFO - Safety margin: 0.02
# Y-scrambling:   0%|          | 0/300 [00:00<?, ?it/s]
# Running y-scrambling for estimator: LOGREG_l2_0.1_SFS
# Y-scrambling: 100%|██████████| 300/300 [00:01<00:00, 238.38it/s]
# 2026-08-04 14:59:54,041 - mlchem.ml.modelling.model_evaluation - INFO - Probability to obtain a better model by chance: 0.000
# 2026-08-04 14:59:54,041 - mlchem.ml.modelling.model_evaluation - INFO - Safety margin: 0.18
# Y-scrambling:   0%|          | 0/300 [00:00<?, ?it/s]
# Running y-scrambling for estimator: LOGREG_l2_10_COMB
# Y-scrambling: 100%|██████████| 300/300 [00:01<00:00, 220.71it/s]
# 2026-08-04 14:59:55,498 - mlchem.ml.modelling.model_evaluation - INFO - Probability to obtain a better model by chance: 0.003
# 2026-08-04 14:59:55,498 - mlchem.ml.modelling.model_evaluation - INFO - Safety margin: -0.02
# Y-scrambling:  13%|█▎        | 38/300 [00:00<00:00, 374.80it/s]
# Running y-scrambling for estimator: LOGREG_l2_10_SFS
# Y-scrambling: 100%|██████████| 300/300 [00:01<00:00, 237.90it/s]
# 2026-08-04 14:59:56,866 - mlchem.ml.modelling.model_evaluation - INFO - Probability to obtain a better model by chance: 0.000
# 2026-08-04 14:59:56,867 - mlchem.ml.modelling.model_evaluation - INFO - Safety margin: 0.04
# Y-scrambling:  10%|▉         | 29/300 [00:00<00:01, 254.29it/s]
# Running y-scrambling for estimator: LOGREG_l2_1_COMB
# Y-scrambling: 100%|██████████| 300/300 [00:01<00:00, 205.26it/s]
# 2026-08-04 14:59:58,410 - mlchem.ml.modelling.model_evaluation - INFO - Probability to obtain a better model by chance: 0.000
# 2026-08-04 14:59:58,410 - mlchem.ml.modelling.model_evaluation - INFO - Safety margin: 0.01
# Y-scrambling:   0%|          | 0/300 [00:00<?, ?it/s]
# Running y-scrambling for estimator: LOGREG_l2_1_SFS
# Y-scrambling: 100%|██████████| 300/300 [00:01<00:00, 231.16it/s]
# 2026-08-04 14:59:59,810 - mlchem.ml.modelling.model_evaluation - INFO - Probability to obtain a better model by chance: 0.000
# 2026-08-04 14:59:59,811 - mlchem.ml.modelling.model_evaluation - INFO - Safety margin: 0.02
#                        estimator  safety_margin
# 3                      KNN_5_SFS           0.26
# 0                     KNN_3_COMB           0.18
# 27             LOGREG_l2_0.1_SFS           0.18
# 1                      KNN_3_SFS           0.12
# 5                      KNN_7_SFS           0.12
# 7                      KNN_9_SFS           0.11
# 6                     KNN_9_COMB           0.11
# 4                     KNN_7_COMB           0.10
# 24              LOGREG_l1_1_COMB           0.05
# 2                     KNN_5_COMB           0.05
# 25               LOGREG_l1_1_SFS           0.04
# 23              LOGREG_l1_10_SFS           0.04
# 29              LOGREG_l2_10_SFS           0.04
# 9     LOGREG_l1ratio_0_C_0.1_SFS           0.02
# 26            LOGREG_l2_0.1_COMB           0.02
# 31               LOGREG_l2_1_SFS           0.02
# 14   LOGREG_l1ratio_1_C_0.1_COMB           0.01
# 30              LOGREG_l2_1_COMB           0.01
# 17    LOGREG_l1ratio_1_C_1.0_SFS           0.00
# 21             LOGREG_l1_0.1_SFS           0.00
# 16   LOGREG_l1ratio_1_C_1.0_COMB           0.00
# 10   LOGREG_l1ratio_0_C_1.0_COMB           0.00
# 12  LOGREG_l1ratio_0_C_10.0_COMB          -0.01
# 13   LOGREG_l1ratio_0_C_10.0_SFS          -0.01
# 22             LOGREG_l1_10_COMB          -0.02
# 15    LOGREG_l1ratio_1_C_0.1_SFS          -0.02
# 11    LOGREG_l1ratio_0_C_1.0_SFS          -0.02
# 19   LOGREG_l1ratio_1_C_10.0_SFS          -0.02
# 18  LOGREG_l1ratio_1_C_10.0_COMB          -0.02
# 20            LOGREG_l1_0.1_COMB          -0.02
# 28             LOGREG_l2_10_COMB          -0.02
# 8    LOGREG_l1ratio_0_C_0.1_COMB          -0.03
# []

# %% [markdown]
# ### If no estimator passes the threshold, we can select the top n estimators from df_yscrambling

# %%
from mlchem.helper import flatten
estimator_names_restricted = list(flatten(df_yscrambling[['estimator']].head(5).values.tolist()))
estimator_names_restricted
# Out:
# ['KNN_5_SFS', 'KNN_3_COMB', 'LOGREG_l2_0.1_SFS', 'KNN_3_SFS', 'KNN_7_SFS']

# %% [markdown]
# ## Predict

# %%
estimator_names_restricted += ['Y']

mv.estimator_list = [dict_estimators[e_n] for e_n in estimator_names_restricted[:-1]]
mv.df_train_predictions_hard = mv.df_train_predictions_hard[estimator_names_restricted]
mv.df_train_predictions_soft = mv.df_train_predictions_soft[estimator_names_restricted]
mv.df_test_predictions_hard = mv.df_test_predictions_hard[estimator_names_restricted]
mv.df_test_predictions_soft = mv.df_test_predictions_soft[estimator_names_restricted]

# %%
metric_name = 'g_S'
mv.n_jobs=-1
mv.predict(metric=get_geometric_S,metric_name=metric_name,n_estimators_max=3)
# Out:
# Evaluating combinations: 100%|██████████| 15/15 [00:00<00:00, 158.07it/s]

# %%
mv.final_results['√(train*test)'] = (mv.final_results[f'{metric_name}_train']*mv.final_results[f'{metric_name}_train'])**0.5
mv.final_results.sort_values(['g_S_test','√(train*test)'],ascending=False).head()
# Out:
#                                                     g_S_train  g_S_test  \
# ['KNN_5_SFS', 'LOGREG_l2_0.1_SFS', 'KNN_3_SFS']...   0.947231  0.941335
# ['LOGREG_l2_0.1_SFS', 'KNN_3_SFS', 'KNN_7_SFS']...   0.947231  0.941335
# ['KNN_5_SFS', 'KNN_3_COMB', 'LOGREG_l2_0.1_SFS'...   0.946988  0.941335
# ['KNN_5_SFS']_soft                                   0.945178  0.941335
# ['KNN_5_SFS']_hard                                   0.945178  0.941335
#
#                                                     √(train*test)
# ['KNN_5_SFS', 'LOGREG_l2_0.1_SFS', 'KNN_3_SFS']...       0.947231
# ['LOGREG_l2_0.1_SFS', 'KNN_3_SFS', 'KNN_7_SFS']...       0.947231
# ['KNN_5_SFS', 'KNN_3_COMB', 'LOGREG_l2_0.1_SFS'...       0.946988
# ['KNN_5_SFS']_soft                                       0.945178
# ['KNN_5_SFS']_hard                                       0.945178

# %% [markdown]
# ## Apply best estimators

# %%
best_cols = ['KNN_5_SFS', 'LOGREG_l2_0.1_SFS', 'KNN_3_SFS']

hard = True

best_cols_Y = best_cols+['Y']


if hard == True:
    from scipy.stats import mode
    df = mv.df_test_predictions_hard[best_cols_Y]
    df['Y_pred'] = df[best_cols].mode(axis=1)
    df_train_predictions = mv.df_train_predictions_hard
    df_test_predictions = mv.df_test_predictions_hard
else:
    df = mv.df_test_predictions_soft[best_cols_Y]
    df['Y_pred_proba'] = df[best_cols].mean(axis=1)
    df['Y_pred'] = round(df['Y_pred_proba'])
    df_train_predictions = mv.df_train_predictions_soft
    df_test_predictions = mv.df_test_predictions_soft
df
# Out:
#                            KNN_5_SFS  LOGREG_l2_0.1_SFS  KNN_3_SFS  Y  Y_pred
# SMILES
# C#C[SH]=O                          1                  0          1  1       1
# CCCCBC=CCCC=O                      1                  1          1  1       1
# C1=CCCC=1                          1                  1          1  1       1
# C=C(C)C                            1                  1          1  1       1
# CCCN1CCC2=C1C2C                    1                  1          1  1       1
# ...                              ...                ...        ... ..     ...
# CC=CCN=CC                          1                  1          1  1       1
# CCCCN1C=C1O                        0                  0          0  0       0
# CNCCCCCO                           0                  0          0  0       0
# CC(C)=CCCF                         1                  0          1  1       1
# CCCCC#SCCCCC=NCCC=CCCCCCC          1                  1          1  1       1
#
# [120 rows x 5 columns]

# %%
from mlchem.metrics import get_sensitivity, get_specificity
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
if hard == True:
    y_pred = np.hstack(np.round(df_train_predictions[best_cols].mode(axis=1).values))
    conf_matrix = confusion_matrix(y_train,y_pred)
    print(f'Sensitivity: {get_sensitivity(y_train,y_pred):.3f}')
    print(f'Specificity: {get_specificity(y_train,y_pred):.3f}')
else:
    y_pred = np.hstack(np.round(df_train_predictions[best_cols].mean(axis=1).values))
    conf_matrix = confusion_matrix(y_train,y_pred)
    print(f'Sensitivity: {get_sensitivity(y_train,y_pred):.3f}')
    print(f'Specificity: {get_specificity(y_train,y_pred):.3f}')

# Define labels for the axes
labels = ['0', '1']
columns = ['0', '1']

# Create a DataFrame for better labeling
conf_df = pd.DataFrame(conf_matrix, index=labels, columns=columns)

# Plot the heatmap
plt.figure(figsize=(5, 4))
sns.heatmap(conf_df, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix - Training')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.tight_layout()
# Out:
# Sensitivity: 0.932
# Specificity: 0.963

# %%
from mlchem.metrics import get_sensitivity, get_specificity
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

if hard == True:
    y_pred = np.hstack(np.round(df_test_predictions[best_cols].mode(axis=1).values))
    conf_matrix = confusion_matrix(y_test,y_pred)
    print(f'Sensitivity: {get_sensitivity(y_test,y_pred):.3f}')
    print(f'Specificity: {get_specificity(y_test,y_pred):.3f}')
else:
    y_pred = np.hstack(np.round(df_test_predictions[best_cols].mean(axis=1).values))
    conf_matrix = confusion_matrix(y_test,y_pred)
    print(f'Sensitivity: {get_sensitivity(y_test,y_pred):.3f}')
    print(f'Specificity: {get_specificity(y_test,y_pred):.3f}')

# Define labels for the axes
labels = ['0', '1']
columns = ['0', '1']

# Create a DataFrame for better labeling
conf_df = pd.DataFrame(conf_matrix, index=labels, columns=columns)

# Plot the heatmap
plt.figure(figsize=(5, 4))
sns.heatmap(conf_df, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix - Test')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.tight_layout()
# Out:
# Sensitivity: 0.917
# Specificity: 0.967
